# %% [markdown]
# <a href="https://colab.research.google.com/github/monicalimachi/codelabv1/blob/wids_datathom_s1/Colab_Python_inicial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python en Ciencia de Datos**

# %% [markdown]
# # Ciencia de datos![datascience.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ✅ # Porque usamos Python?
# - Open source - free
# - Simple e intuitivo
# - Bibliotecas especializadas para analisis de datos y otras areas:
#   - https://pandas.pydata.org/
#   - https://numpy.org/
#   - https://plotly.com/python/
#   - https://scikit-learn.org/
#   - https://keras.io/
#
# - Tiene una gran comunidad que la soporta, documentacion en diversos idiomas:
#   - https://docs.python.org/es/3/tutorial/
# - Soporta grandes cantidades de valores
#
#
# ❎ Desventajas:
# - Se necesita entender lo basico de programacion
#
# # Extraccion de Datos
# - SQL
# - Formatos de achivos: XML, CSV,JSON
#
# # Limpieza de Datos
# - Revision de datos vacios, no validos
# - Recopilacion de datos relevantes
#
# # Analisis
# - Desarrollo de modelos estadisticos
# - Visualizacion y representaciones
# - Analisis estadistico
# - Reportes

# %% [markdown]
# ---

# %% [markdown]
# # Pasos para comenzar:
#
# - Programación basica en Python
#   - Cursos en linea: freecodecamp español, udemy, platzi,codigofacilito
#   - Bootcamps
# - Configurar el entorno
#   - Colab
#   - Jupyter notebook
#   - Kagle

# %% [markdown]
# - Jupyter notebook:
#
# https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html#installing-conda-on-a-system-that-has-other-python-installations-or-packages

# %% [markdown]
# ---

# %% [markdown]
# # Repasando temas basicos en Python
#
# 1. Puedes agregar notas en cada celda de tipo codigo si por delante pones #

# %%
# Hola
print ('Hello World')
# Out:
# Hello World

# %%
"Holaaa"
# Out:
# 'Holaaa'

# %%
sys.stdout.write ("My Hello 2 \n")
print ("---- Hello mundo ----- ")
print ("Hola mundo ")
# Out:
# My Hello 2
# ---- Hello mundo -----
# Hola mundo

# %% [markdown]
# 2. El programa en python es una serie de expresiones y declaraciones

# %%
#Statement Declaracion
49
# Out:
# 49

# %%
#Expression
a=49

# %%
print (a)
# Out:
# 49

# %%
#Floating Point Number
4.5555
# Out:
# 4.5555

# %%
#Numeros complejos
complex(1,5)
# Out:
# (1+5j)

# %%
#type (expression)
type(5)
# Out:
# int

# %%
type(5.7778)
# Out:
# float

# %%
type (complex(4,3))
# Out:
# complex

# %% [markdown]
# # **Expresiones aritmeticas**

# %% [markdown]
# Operadores Aritmeticos
#  * (+)   Sum
#  * (-)    Res
#  * (*)   Mult
#  * (/)  Div
#  * (**) Exp
#
# Others
# * (/ /) Floor Div
# * (%) Mod

# %%
# +
a=10
print (a+2)
# Out:
# 12

# %%
# -
print (a-2)
# Out:
# 8

# %%
# *
print (a*2)
# Out:
# 20

# %%
# /
print (a/2)
# Out:
# 5.0

# %%
# **
a=5 
b=3
print (a**b)
# Out:
# 125

# %%
# / /
print (17 // 8)
# Out:
# 2

# %%
# %
print (5%3)
# Out:
# 2

# %% [markdown]
# # **Expresiones**

# %%
# variable = valor_expression
a= 20000.9999
b= 10
c= a+b
print (c)
# Out:
# 20010.9999

# %%
a=7
a=a*2
print(a)
# Out:
# 14

# %%
a=7
a*=2
print(a)
# Out:
# 14

# %% [markdown]
# # **Logica**

# %% [markdown]
# if condition:
#
#     if_block_statement

# %%
# Condicion y resultado
if True:
  print("True!!!!!")
# Out:
# True!!!!!

# %%
#Other
a=3
if a!=3:
  print(a)
else:
  print ("a=3")
# Out:
# a=3

# %% [markdown]
# # **Logica con Funciones**

# %%
#Declarar y nombrar la funcion
def add(a,b):
  c= a + b
  return c
#Llamar a la funcion
add (10,15)
# Out:
# 25

# %% [markdown]
# Condicionales:  (bool for short)
#
#     In  [1]: type(True)
#     Out [1]: bool
#
#     In  [2]: type(False)
#     Out [2]: bool

# %%
a=3
print (a!=3)
# Out:
# False

# %%
def add_divisible(a,b):
  if a % 2 ==0:
    return a+b
  else:
    print ('a no es divisible')
    return None
  
add_divisible(18,3)
# Out:
# 21

# %% [markdown]
# # ***Recursos***
# -

# %% [markdown]
# # Comunidades de Python
#
# - WiDS La Paz >> @WiDS_LaPaz
# - Python La Paz >>
# - Pyladies La Paz >>
# - Pyladies Cochabamba >>
# - Pyladies El Alto >>
# - RLadies La Paz >>
